# %%
import seaborn as sns
import pandas as pd
a=sns.load_dataset("exercise")
print(a)
a.to_csv("exercise_dataset.csv",index=False)
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
df=pd.read_csv("/content/exercise_dataset.csv")
print(df.head(10))
print(df.tail(10))
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest
# 5           5   2  low fat     93  30 min  rest
# 6           6   3  low fat     97   1 min  rest
# 7           7   3  low fat     97  15 min  rest
# 8           8   3  low fat     94  30 min  rest
# 9           9   4  low fat     80   1 min  rest
#     Unnamed: 0  id    diet  pulse    time     kind
# 80          80  27  no fat    140  30 min  running
# 81          81  28  no fat    103   1 min  running
# 82          82  28  no fat    124  15 min  running
# 83          83  28  no fat    140  30 min  running
# 84          84  29  no fat     94   1 min  running
# 85          85  29  no fat    135  15 min  running
# 86          86  29  no fat    130  30 min  running
# ...

# %%
df=pd.read_csv("/content/exercise_dataset.csv")
print(df.describe())
print(df.describe().T)
print(df.shape)
print(df.shape[0])
print(df.shape[1])
# Out:
#        Unnamed: 0         id       pulse
# count   90.000000  90.000000   90.000000
# mean    44.500000  15.500000   99.700000
# std     26.124701   8.703932   14.858471
# min      0.000000   1.000000   80.000000
# 25%     22.250000   8.000000   90.250000
# 50%     44.500000  15.500000   96.000000
# 75%     66.750000  23.000000  103.000000
# max     89.000000  30.000000  150.000000
#             count  mean        std   min    25%   50%     75%    max
# Unnamed: 0   90.0  44.5  26.124701   0.0  22.25  44.5   66.75   89.0
# id           90.0  15.5   8.703932   1.0   8.00  15.5   23.00   30.0
# pulse        90.0  99.7  14.858471  80.0  90.25  96.0  103.00  150.0
# (90, 6)
# 90
# 6

# %%
df=pd.read_csv("/content/exercise_dataset.csv")
print(df.columns)#print labels
# Out:
# Index(['Unnamed: 0', 'id', 'diet', 'pulse', 'time', 'kind'], dtype='object')

# %%
df=pd.read_csv("/content/exercise_dataset.csv")
df2=df.copy()
df2.loc[1:3,'pulse']=None
df2.head(10)
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat   85.0   1 min  rest
# 1           1   1  low fat    NaN  15 min  rest
# 2           2   1  low fat    NaN  30 min  rest
# 3           3   2  low fat    NaN   1 min  rest
# 4           4   2  low fat   92.0  15 min  rest
# 5           5   2  low fat   93.0  30 min  rest
# 6           6   3  low fat   97.0   1 min  rest
# 7           7   3  low fat   97.0  15 min  rest
# 8           8   3  low fat   94.0  30 min  rest
# 9           9   4  low fat   80.0   1 min  rest

# %%
print(df2.isnull().sum())
# Out:
# Unnamed: 0    0
# id            0
# diet          0
# pulse         3
# time          0
# kind          0
# dtype: int64

# %%
print(df2['diet'])
# Out:
# 0     low fat
# 1     low fat
# 2     low fat
# 3     low fat
# 4     low fat
#        ...
# 85     no fat
# 86     no fat
# 87     no fat
# 88     no fat
# 89     no fat
# Name: diet, Length: 90, dtype: object

# %%
9print(df[df.index==33])
# Out:
#     Unnamed: 0  id     diet  pulse   time     kind
# 33          33  12  low fat     93  1 min  walking

# %%
print(df[df.index.isin(range(0,4))])
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest

# %%
print(df2.loc[3])
# Out:
# Unnamed: 0          3
# id                  2
# diet          low fat
# pulse             NaN
# time            1 min
# kind             rest
# Name: 3, dtype: object

# %%
df2.loc[[30,33,3]]
# Out:
#     Unnamed: 0  id     diet  pulse   time     kind
# 30          30  11  low fat   86.0  1 min  walking
# 33          33  12  low fat   93.0  1 min  walking
# 3            3   2  low fat    NaN  1 min     rest

# %%
df2.loc[10:15,['diet','pulse',]]
# Out:
#        diet  pulse
# 10  low fat   82.0
# 11  low fat   83.0
# 12  low fat   91.0
# 13  low fat   92.0
# 14  low fat   91.0
# 15   no fat   83.0

# %%
df2.iloc[1:4, :4]
# Out:
#    Unnamed: 0  id     diet  pulse
# 1           1   1  low fat    NaN
# 2           2   1  low fat    NaN
# 3           3   2  low fat    NaN

# %%
df2.loc[df['pulse']=='85']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, id, diet, pulse, time, kind]
# Index: []

# %%
df2.dropna(inplace=True,axis=1)
df2
# Out:
#     Unnamed: 0  id     diet    time     kind
# 0            0   1  low fat   1 min     rest
# 1            1   1  low fat  15 min     rest
# 2            2   1  low fat  30 min     rest
# 3            3   2  low fat   1 min     rest
# 4            4   2  low fat  15 min     rest
# ..         ...  ..      ...     ...      ...
# 85          85  29   no fat  15 min  running
# 86          86  29   no fat  30 min  running
# 87          87  30   no fat   1 min  running
# 88          88  30   no fat  15 min  running
# 89          89  30   no fat  30 min  running
#
# [90 rows x 5 columns]

# %%
mv=df['pulse'].mean()
df2=df2.fillna(mv)
print(df2)
print(mv)
# Out:
#     Unnamed: 0  id     diet    time     kind
# 0            0   1  low fat   1 min     rest
# 1            1   1  low fat  15 min     rest
# 2            2   1  low fat  30 min     rest
# 3            3   2  low fat   1 min     rest
# 4            4   2  low fat  15 min     rest
# ..         ...  ..      ...     ...      ...
# 85          85  29   no fat  15 min  running
# 86          86  29   no fat  30 min  running
# 87          87  30   no fat   1 min  running
# 88          88  30   no fat  15 min  running
# 89          89  30   no fat  30 min  running
#
# [90 rows x 5 columns]
# 99.7

# %%
from google.colab import drive
drive.mount('/content/drive')
