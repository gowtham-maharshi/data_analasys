# %%
import requests

url = "https://text-translator2.p.rapidapi.com/translate"

payload = {
	"source_language": "en",
	"target_language": "id",
	"text": "What is your name?"
}
headers = {
	"content-type": "application/x-www-form-urlencoded",
	"X-RapidAPI-Key": "b62bd19712msh30080521113576fp11a8e1jsn5439f9b55e8d",
	"X-RapidAPI-Host": "text-translator2.p.rapidapi.com"
}

response = requests.post(url, data=payload, headers=headers)

print(response.json())
# Out:
# {'status': 'success', 'data': {'translatedText': 'Siapa namamu?'}}

# %%
import requests

url = "https://local-business-data.p.rapidapi.com/search"

querystring = {"query":"Hotels in San Francisco, USA","limit":"20","lat":"37.359428","lng":"-121.925337","zoom":"13","language":"en","region":"us"}

headers = {
	"X-RapidAPI-Key": "b62bd19712msh30080521113576fp11a8e1jsn5439f9b55e8d",
	"X-RapidAPI-Host": "local-business-data.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'status': 'OK', 'request_id': '5bd8a14c-9447-4d37-ab0b-ecef5bac660b', 'parameters': {'query': 'Hotels in San Francisco, USA', 'language': 'en', 'region': 'us', 'lat': 37.359428, 'lng': -121.925337, 'zoom': 13, 'limit': 20, 'offset': 0}, 'data': [{'business_id': '0x8085808b287f3b3b:0xa49802f84f7ddb35', 'google_id': '0x8085808b287f3b3b:0xa49802f84f7ddb35', 'place_id': 'ChIJOzt_KIuAhYARNdt9T_gCmKQ', 'google_mid': '/m/06618ms', 'phone_number': '+14154336600', 'name': 'Hilton San Francisco Financial District', 'latitude': 37.7952284, 'longitude': -122.40407289999999, 'full_address': 'Hilton San Francisco Financial District, 750 Kearny St, San Francisco, CA 94108', 'review_count': 4981, 'rating': 3.9, 'timezone': 'America/Los_Angeles', 'working_hours': None, 'website': 'https://www.hilton.com/en/hotels/sfofdhf-hilton-san-francisco-financial-district/?SEO_id=GMB-AMER-HH-SFOFDHF&y_source=1_MTIyMDk1Ni03MTUtbG9jYXRpb24ud2Vic2l0ZQ%3D%3D', 'verified': True, 'place_link': 'https://www.google.com
# ...

# %%
import requests

url = "https://moviesdatabase.p.rapidapi.com/titles/series/%7BseriesId%7D"

headers = {
	"X-RapidAPI-Key": "b62bd19712msh30080521113576fp11a8e1jsn5439f9b55e8d",
	"X-RapidAPI-Host": "moviesdatabase.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'results': []}

# %%
import requests

url = "https://jsearch.p.rapidapi.com/search"

querystring = {"query":"Python developer in Texas, USA","page":"1","num_pages":"1"}

headers = {
	"X-RapidAPI-Key": "b62bd19712msh30080521113576fp11a8e1jsn5439f9b55e8d",
	"X-RapidAPI-Host": "jsearch.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'status': 'OK', 'request_id': '90e529fd-f08f-4c19-ba03-eefac039cf04', 'parameters': {'query': 'python developer in texas, usa', 'page': 1, 'num_pages': 1}, 'data': [{'job_id': 'Se73RDMZ0mXU9x1jAAAAAA==', 'employer_name': 'Reece USA', 'employer_logo': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQk3AoGfUp8KCgyugkW89_iK-oXwaCuTX5bH2Kd&s=0', 'employer_website': None, 'employer_company_type': None, 'job_publisher': 'LinkedIn', 'job_employment_type': 'FULLTIME', 'job_title': 'Python Developer', 'job_apply_link': 'https://www.linkedin.com/jobs/view/python-developer-at-reece-usa-3842330537', 'job_apply_is_direct': False, 'job_apply_quality_score': 0.6768, 'apply_options': [{'publisher': 'LinkedIn', 'apply_link': 'https://www.linkedin.com/jobs/view/python-developer-at-reece-usa-3842330537', 'is_direct': False}, {'publisher': 'Jobright AI', 'apply_link': 'https://jobright.ai/jobs/info/65e04a99575dfd5a802a4bd0', 'is_direct': False}], 'job_description': 'PLEASE NOTE THIS IS A PERMANE
# ...
